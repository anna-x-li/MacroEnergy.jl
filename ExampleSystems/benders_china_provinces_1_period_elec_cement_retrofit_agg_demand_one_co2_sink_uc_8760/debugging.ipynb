# %%
import pandas as pd
import numpy as np

# %%
fuel_work = pd.read_csv("/Users/al3792/Documents_Local/MacroEnergy.jl/ExampleSystems/china_provinces_1_period_elec_cement_retrofit_agg_demand_one_co2_sink_uc/system/fuel_prices_1.csv")

# %%
fuel_not_work = pd.read_csv("/Users/al3792/Documents_Local/MacroEnergy.jl/ExampleSystems/china_provinces_1_period_elec_cement_retrofit_agg_demand_one_co2_sink_uc_8760/system/fuel_prices_1.csv")

# %%
fuel_not_work.isna().sum().sum()
# Out:
# 8472

# %%
vre_work = pd.read_csv("/Users/al3792/Documents_Local/MacroEnergy.jl/ExampleSystems/china_provinces_1_period_elec_cement_retrofit_agg_demand_one_co2_sink_uc/system/vre_availability_1.csv")

# %%
vre_not_work = pd.read_csv("/Users/al3792/Documents_Local/MacroEnergy.jl/ExampleSystems/china_provinces_1_period_elec_cement_retrofit_agg_demand_one_co2_sink_uc_8760/system/vre_availability_1.csv")

# %%
vre_work.columns.equals(vre_not_work.columns)
# Out:
# True

# %%
vre_not_work.isna().sum().sum()
# Out:
# 0

# %%
demand_work = pd.read_csv("/Users/al3792/Documents_Local/MacroEnergy.jl/ExampleSystems/china_provinces_1_period_elec_cement_retrofit_agg_demand_one_co2_sink_uc/system/demand_1.csv")

# %%
demand_not_work = pd.read_csv("/Users/al3792/Documents_Local/MacroEnergy.jl/ExampleSystems/china_provinces_1_period_elec_cement_retrofit_agg_demand_one_co2_sink_uc_8760/system/demand_1.csv")

# %%
demand_work.columns.equals(demand_not_work.columns)
# Out:
# True

# %%
demand_not_work.isna().sum().sum()
# Out:
# 0
